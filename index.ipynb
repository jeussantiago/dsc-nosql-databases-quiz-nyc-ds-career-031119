# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# SQL Database is a Relational Database and a structured one whereas NoSQL is Non-relational database likely to be more document and distributed than structured.
#
#
#
# You might ask what exactly mean Relational Database?
#
#
#
# Relational database strictly adheres relations where it is divided into the set of rows and columns to store data often named as tables, but the Non-relational database has a document-oriented or distributed storage which doesn’t require any table structure.
#
#
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
# NoSQL uses hierarchical data storage, and there is no hierarchical data storage for SQL.
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# NoSQL/MongoDB uses hierarchical data storage, and there is no hierarchical data storage for SQL. It uses a key-value Storing system, comparable to dictionaries in Python. It differs from SQL in that each document has it's own schema
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# Fault Tolerance is the property that allows machines to continue running in the event of any failures. This relates to RDDs because RDDs are fault tolerant in that they save their informations on multiple servers in case a few servers go down and you're not trapped waiting for the server to come back up.
#
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# The "Map" is MapReduce is the process of running the same process on multiple machines
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
